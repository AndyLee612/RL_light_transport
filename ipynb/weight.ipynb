# %%
import pandas as pd
import os
import torch
import sys

# %%
sys.path.append('/mnt/train-data-1-hdd/andy_lee/projects/ZSRL_Light_Transport')

# %%
# !ls ../agents/osfb/saved_models/sweep-z50-alpha0_01--seed42/best_model.pt/
# Out:
# best-step0.pickle      best-step40000.pickle  best-step80000.pickle
# best-step20000.pickle  best-step60000.pickle

# %%
data = torch.load('../agents/osfb/saved_models/sweep-z50-alpha0_01--seed42/best_model.pt/best-step300000.pickle',weights_only=False)
# Out:
# /mnt/train-data-1-hdd/andy_lee/projects/ZSRL_Light_Transport/.venv/lib/python3.11/site-packages/glfw/__init__.py:917: GLFWError: (65550) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)

# %%
print(data)
# Out:
# OneStepFB(
#   (FB): OneStepForwardBackwardRepresentation(
#     (forward_representation): OneStepForwardRepresentation(
#       (obs_action_preprocessor): AbstractPreprocessor(
#         (trunk): Sequential(
#           (0): Linear(in_features=9, out_features=1024, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1024, out_features=1024, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=1024, out_features=512, bias=True)
#           (5): ReLU()
#         )
#       )
#       (F1): ForwardModel(
#         (trunk): Sequential(
#           (0): Linear(in_features=512, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=512, out_features=512, bias=True)
#           (3): GELU(approximate='none')
#           (4): Linear(in_features=512, out_features=512, bias=True)
#           (5): GELU(approximate='none')
#           (6): Linear(in_features=512, out_features=512, bias=True)
# ...
